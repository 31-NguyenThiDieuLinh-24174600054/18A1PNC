# %% [markdown]
# bài 1

# %%
import threading
import time

def worker(thread_id):
    thread_name = threading.current_thread().name
    print(f"Luồng {thread_id}: Tên luồng là {thread_name}")
    time.sleep(0.5) 

def bai_6_1_tao_va_in_ten_luong():
    threads = []
    num_threads = 5
    print(f"--- TẠO VÀ IN TÊN {num_threads} LUỒNG ---")

    for i in range(num_threads):
        thread = threading.Thread(target=worker, args=(i+1,), name=f"Thread-{i+1}")
        threads.append(thread)
        thread.start()
    for thread in threads:
        thread.join()

    print("✅ Tất cả các luồng đã hoàn thành.")
bai_6_1_tao_va_in_ten_luong()
# Out:
# --- TẠO VÀ IN TÊN 5 LUỒNG ---
# Luồng 1: Tên luồng là Thread-1
# Luồng 2: Tên luồng là Thread-2
# Luồng 3: Tên luồng là Thread-3
# Luồng 4: Tên luồng là Thread-4
# Luồng 5: Tên luồng là Thread-5
# ✅ Tất cả các luồng đã hoàn thành.

# %% [markdown]
# bài 2

# %%
import threading
import time
import random

def download_file(file_name):
    thread_name = threading.current_thread().name
    download_time = random.uniform(1, 3) 
    
    print(f"[{thread_name}] Bắt đầu tải xuống: {file_name}. Thời gian dự kiến: {download_time:.2f}s")
    time.sleep(download_time)
    print(f"[{thread_name}]  Hoàn thành tải xuống: {file_name}.")

def bai_6_2_tai_xuong_dong_thoi():
    files_to_download = ["File_A.zip", "Image_B.jpg", "Document_C.pdf", "Video_D.mp4"]
    threads = []
    
    print(f"--- BÀI 6.2: MÔ PHỎNG TẢI XUỐNG ĐỒNG THỜI {len(files_to_download)} TỆP ---")

    start_time = time.time()
    
    for file in files_to_download:
        thread = threading.Thread(target=download_file, args=(file,))
        threads.append(thread)
        thread.start()
        
    for thread in threads:
        thread.join()

    end_time = time.time()
    print(f"\nTổng thời gian hoàn thành: {end_time - start_time:.2f} giây.")
bai_6_2_tai_xuong_dong_thoi()
# Out:
# --- BÀI 6.2: MÔ PHỎNG TẢI XUỐNG ĐỒNG THỜI 4 TỆP ---
# [Thread-3 (download_file)] Bắt đầu tải xuống: File_A.zip. Thời gian dự kiến: 2.56s
# [Thread-4 (download_file)] Bắt đầu tải xuống: Image_B.jpg. Thời gian dự kiến: 2.64s
# [Thread-5 (download_file)] Bắt đầu tải xuống: Document_C.pdf. Thời gian dự kiến: 1.67s
# [Thread-6 (download_file)] Bắt đầu tải xuống: Video_D.mp4. Thời gian dự kiến: 1.55s
# [Thread-6 (download_file)]  Hoàn thành tải xuống: Video_D.mp4.
# [Thread-5 (download_file)]  Hoàn thành tải xuống: Document_C.pdf.
# [Thread-3 (download_file)]  Hoàn thành tải xuống: File_A.zip.
# [Thread-4 (download_file)]  Hoàn thành tải xuống: Image_B.jpg.
#
# Tổng thời gian hoàn thành: 2.64 giây.

# %% [markdown]
# bài 3

# %%
import threading

def tim_so_chan(start, end):
    chan_list = [i for i in range(start, end + 1) if i % 2 == 0]
    print(f"\n[Luồng CHẴN] Các số chẵn từ {start} đến {end}: {chan_list}")

def tim_so_le(start, end):
    le_list = [i for i in range(start, end + 1) if i % 2 != 0]
    print(f"\n[Luồng LẺ] Các số lẻ từ {start} đến {end}: {le_list}")

def bai_6_3_tim_so_chan_le():
    start_range = 30
    end_range = 50
    print(f"--- TÌM SỐ CHẴN/LẺ (TỪ {start_range} ĐẾN {end_range}) BẰNG HAI LUỒNG ---")
    t_chan = threading.Thread(target=tim_so_chan, args=(start_range, end_range), name="Chan_Thread")
    
    t_le = threading.Thread(target=tim_so_le, args=(start_range, end_range), name="Le_Thread")
    
    t_chan.start()
    t_le.start()

    t_chan.join()
    t_le.join()

    print("\n Cả hai luồng đã hoàn thành việc tìm kiếm.")

bai_6_3_tim_so_chan_le()
# Out:
# --- BÀI 6.3: TÌM SỐ CHẴN/LẺ (TỪ 30 ĐẾN 50) BẰNG HAI LUỒNG ---
#
# [Luồng CHẴN] Các số chẵn từ 30 đến 50: [30, 32, 34, 36, 38, 40, 42, 44, 46, 48, 50]
#
# [Luồng LẺ] Các số lẻ từ 30 đến 50: [31, 33, 35, 37, 39, 41, 43, 45, 47, 49]
#
#  Cả hai luồng đã hoàn thành việc tìm kiếm.

# %% [markdown]
# bài 4

# %%
import threading
import math
from functools import reduce

partial_results = [] 
lock = threading.Lock()

def calculate_partial_product(start, end):
    current_product = 1
    for i in range(start, end + 1):
        current_product *= i
    
    with lock:
        partial_results.append(current_product)
    
    print(f"[{threading.current_thread().name}] Tính tích từ {start} đến {end}. Kết quả cục bộ: {current_product}")

def bai_6_4_tinh_giai_thua_da_luong(n, num_threads=4):
    global partial_results
    partial_results = []
    
    print(f"--- TÍNH GIAI THỪA CỦA {n} BẰNG {num_threads} LUỒNG ---")
    
    threads = []
    chunk_size = math.ceil(n / num_threads) 

    for i in range(num_threads):
        start = i * chunk_size + 1
        end = min((i + 1) * chunk_size, n)

        if start > n:
            break
        
        thread = threading.Thread(target=calculate_partial_product, args=(start, end), name=f"Factorial_Thread_{i+1}")
        threads.append(thread)
        thread.start()

    for thread in threads:
        thread.join()
    final_result = reduce(lambda x, y: x * y, partial_results)
    math_result = math.factorial(n)
    
    print(f"\nKết quả đa luồng ({len(partial_results)} tích): {final_result}")
    print(f"Kết quả thư viện math.factorial({n}): {math_result}")
    print(f"Kết quả tính toán khớp: {final_result == math_result}")

bai_6_4_tinh_giai_thua_da_luong(15, num_threads=4)
# Out:
# --- TÍNH GIAI THỪA CỦA 15 BẰNG 4 LUỒNG ---
# [Factorial_Thread_1] Tính tích từ 1 đến 4. Kết quả cục bộ: 24
# [Factorial_Thread_2] Tính tích từ 5 đến 8. Kết quả cục bộ: 1680
# [Factorial_Thread_3] Tính tích từ 9 đến 12. Kết quả cục bộ: 11880
# [Factorial_Thread_4] Tính tích từ 13 đến 15. Kết quả cục bộ: 2730
#
# Kết quả đa luồng (4 tích): 1307674368000
# Kết quả thư viện math.factorial(15): 1307674368000
# Kết quả tính toán khớp: True

# %% [markdown]
# bài 5

# %%
import threading
import requests
import time
URLS = [
    "https://jsonplaceholder.typicode.com/posts/1",
    "https://jsonplaceholder.typicode.com/users/2",
    "https://jsonplaceholder.typicode.com/comments/3",
    "http://httpbin.org/delay/1" 
]

def fetch_url(url):
    thread_name = threading.current_thread().name
    try:
        start_time = time.time()
        response = requests.get(url, timeout=5) 
        end_time = time.time()
        
        status = response.status_code
        length = len(response.text)
        
        print(f"[{thread_name}]  {url}: Status={status}, Kích thước={length} bytes, Thời gian={end_time - start_time:.2f}s")
        
    except requests.exceptions.RequestException as e:
        print(f"[{thread_name}]  Lỗi khi truy cập {url}: {e}")

def bai_6_5_http_dong_thoi():
    threads = []
    print(f"---  THỰC HIỆN {len(URLS)} YÊU CẦU HTTP ĐỒNG THỜI ---")

    start_total = time.time()

    for url in URLS:
        thread = threading.Thread(target=fetch_url, args=(url,))
        threads.append(thread)
        thread.start()

    for thread in threads:
        thread.join()

    end_total = time.time()
    print(f"\nTổng thời gian hoàn thành (Đa luồng): {end_total - start_total:.2f} giây.")

bai_6_5_http_dong_thoi()
# Out:
# ---  THỰC HIỆN 4 YÊU CẦU HTTP ĐỒNG THỜI ---
# [Thread-9 (fetch_url)]  https://jsonplaceholder.typicode.com/comments/3: Status=200, Kích thước=340 bytes, Thời gian=1.15s
# [Thread-8 (fetch_url)]  https://jsonplaceholder.typicode.com/users/2: Status=200, Kích thước=509 bytes, Thời gian=1.64s
# [Thread-10 (fetch_url)]  http://httpbin.org/delay/1: Status=200, Kích thước=355 bytes, Thời gian=2.59s
# [Thread-7 (fetch_url)]  https://jsonplaceholder.typicode.com/posts/1: Status=200, Kích thước=292 bytes, Thời gian=2.59s
#
# Tổng thời gian hoàn thành (Đa luồng): 2.60 giây.

# %% [markdown]
# bài 6

# %%
import threading
import time 
lock = threading.Lock()
can_print_even = True 

def in_so_chan(max_num):
    global can_print_even
    for i in range(2, max_num + 1, 2):
        with lock:
            while not can_print_even:
                lock.release() 
                time.sleep(0.001)
                lock.acquire()
                
            print(f"[Luồng CHẴN] {i}")
            can_print_even = False 
def in_so_le(max_num):
    global can_print_even
    for i in range(1, max_num + 1, 2):
        with lock:
            while can_print_even:
                lock.release()
                time.sleep(0.001)
                lock.acquire()
                
            print(f"[Luồng LẺ] {i}")
            can_print_even = True 

def bai_6_6_in_xen_ke_chan_le(max_num=20):
    global can_print_even, lock
    can_print_even = True 
    lock = threading.Lock()
    
    print(f"--- BÀI 6.6: IN SỐ CHẴN/LẺ XEN KẼ ĐẾN {max_num} ---")

    t_chan = threading.Thread(target=in_so_chan, args=(max_num,), name="Even_Thread")
    t_le = threading.Thread(target=in_so_le, args=(max_num,), name="Odd_Thread")
    
    t_le.start() 
    t_chan.start() 
    
    t_chan.join()
    t_le.join()

    print("\n Quá trình in xen kẽ đã hoàn thành.")
bai_6_6_in_xen_ke_chan_le(10)
# Out:
# --- BÀI 6.6: IN SỐ CHẴN/LẺ XEN KẼ ĐẾN 10 ---
# [Luồng CHẴN] 2
# [Luồng LẺ] 1
# [Luồng CHẴN] 4
# [Luồng LẺ] 3
# [Luồng CHẴN] 6
# [Luồng LẺ] 5
# [Luồng CHẴN] 8
# [Luồng LẺ] 7
# [Luồng CHẴN] 10
# [Luồng LẺ] 9
#
#  Quá trình in xen kẽ đã hoàn thành.

# %% [markdown]
# bài 7

# %%
import threading
import time
import random
from datetime import datetime

MAX_RUNTIME = 10 

class WebCrawler(threading.Thread):
    def __init__(self, name, interval):
        super().__init__(name=name)
        self.stop_event = threading.Event()
        self.interval = interval 
        self.start_time = time.time()
        self.print_count = 0

    def run(self):
        print(f"Starting {self.name}")

        while not self.stop_event.is_set():
            if time.time() - self.start_time >= MAX_RUNTIME + random.uniform(0, 3):
                break
            
            current_time_str = datetime.now().strftime("Web %b %d %H:%M:%S %Y")
            print(f"{self.name}: {current_time_str}")
            self.print_count += 1
            
            time.sleep(self.interval + random.uniform(0, 0.5)) 

        print(f"Exiting {self.name}")

def bai_6_7_thuc_thi_nhieu_luong():
    print("Starting Main Thread")
    threads = [
        WebCrawler(name="Google", interval=1.5),  
        WebCrawler(name="Yahoo", interval=2.0),
        WebCrawler(name="Facebook", interval=2.5) 
    ]

    for t in threads:
        t.start()

    for t in threads:
        t.join()

    print("Exiting Main Thread")

bai_6_7_thuc_thi_nhieu_luong()
# Out:
# Starting Main Thread
# Starting Google
# Google: Web Dec 17 22:55:37 2025
# Starting Yahoo
# Yahoo: Web Dec 17 22:55:37 2025
# Starting Facebook
# Facebook: Web Dec 17 22:55:37 2025
# Google: Web Dec 17 22:55:39 2025
# Yahoo: Web Dec 17 22:55:39 2025
# Facebook: Web Dec 17 22:55:40 2025
# Google: Web Dec 17 22:55:40 2025
# Yahoo: Web Dec 17 22:55:41 2025
# Google: Web Dec 17 22:55:42 2025
# Facebook: Web Dec 17 22:55:42 2025
# Google: Web Dec 17 22:55:43 2025
# Yahoo: Web Dec 17 22:55:43 2025
# Google: Web Dec 17 22:55:45 2025
# Facebook: Web Dec 17 22:55:45 2025
# Yahoo: Web Dec 17 22:55:46 2025
# Google: Web Dec 17 22:55:47 2025
# Yahoo: Web Dec 17 22:55:48 2025
# Exiting Facebook
# Exiting Google
# Exiting Yahoo
# Exiting Main Thread

# %% [markdown]
# bài 8

# %%
import threading
import random
import math

partial_sums = []
lock = threading.Lock()

def calculate_partial_sum(data_chunk, thread_id):
    current_sum = sum(data_chunk)
    with lock:
        partial_sums.append(current_sum)
    
    data_str = "; ".join(map(str, data_chunk))
    print(f"Thread {thread_id}: {data_str};")


def bai_6_8_tinh_tong_da_luong():
    global partial_sums
    try:
        n = int(input("Nhập số phần tử: ")) 
        num_threads = int(input("Nhập vào số thread: ")) 
    except ValueError:
        print("Lỗi: Đầu vào phải là số nguyên.")
        return

    main_list = [random.randint(0, 10) for _ in range(n)]
    
    print(f"List: {main_list}")
    
    list_length = len(main_list)
    chunk_size = math.ceil(list_length / num_threads) 
    
    threads = []
    partial_sums = [] 
    for i in range(num_threads):
        start_index = i * chunk_size
        end_index = min((i + 1) * chunk_size, list_length)
        
        if start_index >= list_length:
            break
            
        data_chunk = main_list[start_index:end_index]
        
        thread = threading.Thread(
            target=calculate_partial_sum, 
            args=(data_chunk, i + 1), 
            name=f"SumThread_{i + 1}"
        )
        threads.append(thread)
        thread.start()

    for thread in threads:
        thread.join()

    final_total = sum(partial_sums)
    expected_total = sum(main_list)
    print(f"Kiểm tra:{expected_total}")
    
    print(f"\nTổng list={final_total}")
bai_6_8_tinh_tong_da_luong()
# Out:
# List: [9, 10, 3, 8]
# Thread 1: 9;
# Thread 2: 10;
# Thread 3: 3;
# Thread 4: 8;
# Kiểm tra:30
#
# Tổng list=30

# %% [markdown]
# bài 9

# %%
import threading
import time
from datetime import datetime

class WebCrawlerMock(threading.Thread):
    def __init__(self, name, actions):
        super().__init__(name=name)
        self.actions = actions 
        self.start_timestamp = None 

    def run(self):
    
        while self.start_timestamp is None:
            time.sleep(0.001)
        
        print(f"Starting {self.name}")
        
        for delay, message_type in self.actions:
            current_elapsed_time = time.time() - self.start_timestamp
            sleep_duration = delay - current_elapsed_time
            
            if sleep_duration > 0:
                time.sleep(sleep_duration)
            
            
            if message_type == "PRINT":
                
                mock_dt = datetime.fromtimestamp(self.start_timestamp + delay)
                
                current_time_str = mock_dt.strftime("Web %b %d %H:%M:%S %Y") 
                print(f"{self.name}: {current_time_str}")
            elif message_type == "EXIT":
                print(f"Exiting {self.name}")
                break 

def bai_6_9_thuc_thi_nhieu_luong():
    print("Starting Main Thread")
    
    # Google: In (0, 1, 2, 3), thoát (4)
    google_actions = [
        (0, "PRINT"),  # 10:25:52
        (1, "PRINT"),  # 10:25:53
        (2, "PRINT"),  # 10:25:54
        (3, "PRINT"),  # 10:25:55
        (4, "EXIT")    # Exiting Google
    ]

    # Yahoo: In (1, 3, 5, 7), thoát (8)
    yahoo_actions = [
        (1, "PRINT"),  # 10:25:53
        (3, "PRINT"),  # 10:25:55
        (5, "PRINT"),  # 10:25:57
        (7, "PRINT"),  # 10:25:59
        (8, "EXIT")    # Exiting Yahoo
    ]

    # Facebook: In (2, 5, 8, 11), thoát (12)
    facebook_actions = [
        (2, "PRINT"),  # 10:25:54
        (5, "PRINT"),  # 10:25:57
        (8, "PRINT"),  # 10:26:00
        (11, "PRINT"), # 10:26:03
        (12, "EXIT")   # Exiting Facebook
    ]

    threads = [
        WebCrawlerMock(name="Google", actions=google_actions),
        WebCrawlerMock(name="Yahoo", actions=yahoo_actions),
        WebCrawlerMock(name="Facebook", actions=facebook_actions)
    ]

    threads_start_actual_time = time.time() 

    for t in threads:
        t.start_timestamp = threads_start_actual_time 
        t.start()

    for t in threads:
        t.join()

    print("Exiting Main Thread")

bai_6_9_thuc_thi_nhieu_luong()
# Out:
# Starting Main Thread
# Starting Google
# Google: Web Dec 17 22:56:51 2025
# Starting Yahoo
# Starting Facebook
# Google: Web Dec 17 22:56:52 2025
# Yahoo: Web Dec 17 22:56:52 2025
# Facebook: Web Dec 17 22:56:53 2025
# Google: Web Dec 17 22:56:53 2025
# Yahoo: Web Dec 17 22:56:54 2025
# Google: Web Dec 17 22:56:54 2025
# Exiting Google
# Facebook: Web Dec 17 22:56:56 2025
# Yahoo: Web Dec 17 22:56:56 2025
# Yahoo: Web Dec 17 22:56:58 2025
# Exiting YahooFacebook: Web Dec 17 22:56:59 2025
#
# Facebook: Web Dec 17 22:57:02 2025
# Exiting Facebook
# Exiting Main Thread

# %% [markdown]
# bài 10

# %%
import threading
import random
import math

partial_maxes = []
lock = threading.Lock()

def calculate_partial_max(data_chunk, thread_id):
    if not data_chunk:
        return

    local_max = max(data_chunk)
    
    with lock:
        partial_maxes.append(local_max)
    
    data_str = "; ".join(map(str, data_chunk))
    print(f"Thread {thread_id}: {data_str}; -> Max cục bộ: {local_max}")


def bai_6_10_tim_max_da_luong():
    global partial_maxes

    try:
        n = int(input("Nhập số phần tử (N): ")) 
        num_threads = int(input("Nhập vào số thread: ")) 
    except ValueError:
        print("Lỗi: Đầu vào phải là số nguyên.")
        return

    main_list = [random.randint(0, 100) for _ in range(n)]
    
    print(f"\nList ({n} phần tử): {main_list}")
    
    list_length = len(main_list)
    chunk_size = math.ceil(list_length / num_threads) 
    
    threads = []
    partial_maxes = [] 

    for i in range(num_threads):
        start_index = i * chunk_size
        end_index = min((i + 1) * chunk_size, list_length)
        
        if start_index >= list_length:
            break
            
        data_chunk = main_list[start_index:end_index]
        
        thread = threading.Thread(
            target=calculate_partial_max, 
            args=(data_chunk, i + 1), 
            name=f"MaxThread_{i + 1}"
        )
        threads.append(thread)
        thread.start()

    for thread in threads:
        thread.join()
    if partial_maxes:
        final_max = max(partial_maxes)
    else:
        final_max = "Không tìm thấy"
    expected_max = max(main_list) if main_list else "Không tìm thấy"
    print(f"Kiểm tra bằng hàm max() chuẩn :{expected_max}")
    
    print(f"\nMax cục bộ tìm được bởi các Threads: {partial_maxes}")
    print(f"Giá trị lớn nhất trong list (Tìm bằng đa luồng) = {final_max}")
bai_6_10_tim_max_da_luong()
# Out:
# List (6 phần tử): [73, 8, 24, 56, 42, 58]
# Thread 1: 73; -> Max cục bộ: 73
# Thread 2: 8; -> Max cục bộ: 8
# Thread 3: 24; -> Max cục bộ: 24
# Thread 4: 56; -> Max cục bộ: 56
# Thread 5: 42; -> Max cục bộ: 42
# Thread 6: 58; -> Max cục bộ: 58
# Kiểm tra bằng hàm max() chuẩn :73
#
# Max cục bộ tìm được bởi các Threads: [73, 8, 24, 56, 42, 58]
# Giá trị lớn nhất trong list (Tìm bằng đa luồng) = 73
